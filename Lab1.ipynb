# %% [markdown]
# <a href="https://colab.research.google.com/github/mahesh060325/AIML_2303A52037/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PART-01**

# %% [markdown]
# **Part 01: Lab Task is implement the following data structures using Numpy and Pandas.**
#
# 1.Lists
# 2.Arrays
# 3.Identify their type using type()
# 4.Perform mathematical operations on these datasets created - multiplication, division, poweroff
# 5.Combine text with Numpy fuction to generate a textual output - ”Addition of Two: array1 +array 2
# 6.Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
list1 = [1,2,3,4]
list2 = [5,6,7,8]
array1 = np.array(list1)
array2 = np.array(list2)
array1
array2
# Out:
# array([5, 6, 7, 8])

# %%
print(type(list1))
print(type(array1))
print(type(list2))
print(type(array2))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'list'>
# <class 'numpy.ndarray'>

# %% [markdown]
#  **Perform Mathematical Operations on these datasets -Multiplication, Division, Poweroff**

# %%
mul = array1*array2
div = array1/array2
power = np.power(array1,2)

# %%
print("mul of two arrays",mul)
print("div of two arrays",div)
print("power of two arrays",power)
# Out:
# mul of two arrays [ 5 12 21 32]
# div of two arrays [0.2        0.33333333 0.42857143 0.5       ]
# power of two arrays [ 1  4  9 16]

# %% [markdown]
# **Perform Mathematical Operations on these datasets - sin and log operation**

# %%
print("Sine: ",np.sin(array1))
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
print("Exponential: ",np.exp(array1))
# Out:
# Sine:  [ 0.84147098  0.90929743  0.14112001 -0.7568025 ]
# Natural logarithm:  [0.         0.69314718 1.09861229 1.38629436]
# Base-10 logarithm:  [0.         0.30103    0.47712125 0.60205999]
# Base-2 logarithm:  [0.        1.        1.5849625 2.       ]
# Exponential:  [ 2.71828183  7.3890561  20.08553692 54.59815003]

# %%
print("Adding of two arrays:", array1+array2)
# Out:
# Adding of two arrays: [ 6  8 10 12]

# %% [markdown]
# **PART-02**

# %% [markdown]
# **Part-02: Lab Task is to visualize the datasets or data using Matplotlib builtin function Graphs
# Generate Scatterplot
# Let's suppose we collected age (in years), height (in cm), and weight (in kilograms) information from few patients visitng a clinic.**

# %%
import matplotlib.pyplot as plt

# %%
people = ['Mahesh','Chodhitha','Charvika','Tharun','Nikhil','Niteesh',]
age = [17,18,21,26,27,22]
weight = [55,35,77,56,53,56]
height = [170,160,165,156,179,142]

# %%
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %% [markdown]
# **Generate Bar Plot**

# %%
plt.figure(figsize=(12,8))
plt.title("People's weight in kgs",fontsize=18,
          fontstyle='italic')
plt.bar(x=people,height=weight, width=0.7,
        color='blue',edgecolor='k',alpha=0.8)
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=17)
plt.show()

# %% [markdown]
# **Generate Histogram**

# %%
plt.figure(figsize=(9,6))
plt.hist(weight,color='purple',edgecolor='k', alpha=0.75,bins=5)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# **PART-03**

# %% [markdown]
# **Part-03: Access Data from various sources and formats**

# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_table("Lab01-Text.txt")

# %%
data1
# Out:
#    Part 1 – Implement Basic Data Structures using Numpy, Pandas
# 0                                            1. Lists
# 1                                           2. Arrays
# 2                 3. Identify their type using type()
# 3   4. Perform mathematical operations on these da...
# 4                                            poweroff
# 5   5. Combine text with Numpy fuction to generate...
# 6                                     array1 +array 2
# 7     6. Implement np.sin(), log(), log2(), np.exp())
# 8   Part 2 – Visualization of Data using matplotli...
# 9   1. Generate a Data set for Health Care using t...
# 10        people = [’kiran’, arun’, ’vijay’, ’varun’]
# 11                          age =[25, 30, 35, 40, 45]
# 12                       height =[145, 151, 165, 173]
# 13                            weight=[45, 55, 65, 75]
# 14  2. Using the generated dataset given above. Ge...
# 15                   relationships among the vectors.
# 16                                    3. Scatter Plot
# 17                                       4. Bar Chart
# 18                                       5. Histogram
# 19  6. Provide Graph Title, labels for X, Y axis w...
# 20                                         the graph.
# 21  Part 3 – Access Data from Various Data Sources...
# 22  1. Generate your own dataset using MS Excel an...
# 23  it in Google Drive and access it in Google Colab.
# 24  2. Upload the text file using tab seperated va...
# 25  3. Upload the text file using comma seperated ...
# 26               4. Access the excel file using .xlsx
# 27                    5. Access the text from the URL

# %%
data2 = pd.read_csv("Lab01-Text.csv")

# %%
data2
# Out:
#       Part  Task Number                                   Task Description
# 0   Part 1            1         Create and use Lists with Numpy and Pandas
# 1   Part 1            2        Create and use Arrays with Numpy and Pandas
# 2   Part 1            3  Identify the type of Lists and Arrays using ty...
# 3   Part 1            4  Perform mathematical operations on Lists and A...
# 4   Part 1            5  Combine text with Numpy function to generate a...
# 5   Part 1            6  Implement np.sin(), np.log(), np.log2(), np.ex...
# 6   Part 2            1  Generate a dataset for Health Care using the f...
# 7   Part 2            2  Generate a Scatter Plot using the Health Care ...
# 8   Part 2            3  Generate a Bar Chart using the Health Care dat...
# 9   Part 2            4  Generate a Histogram using the Health Care dat...
# 10  Part 2            5  Provide Graph Title, labels for X, Y axis with...
# 11  Part 3            1  Generate your own dataset using MS Excel and N...
# 12  Part 3            2  Upload and access a tab-separated value (.tsv)...
# 13  Part 3            3  Upload and access a comma-separated value (.cs...
# 14  Part 3            4             Access data from an Excel file (.xlsx)
# 15  Part 3            5                        Access text data from a URL

# %%
data3 = pd.read_excel("Height_weight.xlsx")

# %%
data3
# Out:
#         Name  Height (cm)  Weight (kg)
# 0     Mahesh          170           55
# 1  Chodhitha          160           35
# 2   Charvika          165           77
# 3     Tharun          156           56
# 4     Nikhil          179           53
# 5    Niteesh          142           56

# %%
data4 = pd.read_csv("Lab01-Text.tsv", delimiter='\t')

# %%
data4
# Out:
#       Part  Task Number                                   Task Description
# 0   Part 1            1         Create and use Lists with Numpy and Pandas
# 1   Part 1            2        Create and use Arrays with Numpy and Pandas
# 2   Part 1            3  Identify the type of Lists and Arrays using ty...
# 3   Part 1            4  Perform mathematical operations on Lists and A...
# 4   Part 1            5  Combine text with Numpy function to generate a...
# 5   Part 1            6  Implement np.sin(), np.log(), np.log2(), np.ex...
# 6   Part 2            1  Generate a dataset for Health Care using the f...
# 7   Part 2            2  Generate a Scatter Plot using the Health Care ...
# 8   Part 2            3  Generate a Bar Chart using the Health Care dat...
# 9   Part 2            4  Generate a Histogram using the Health Care dat...
# 10  Part 2            5  Provide Graph Title, labels for X, Y axis with...
# 11  Part 3            1  Generate your own dataset using MS Excel and N...
# 12  Part 3            2  Upload and access a tab-separated value (.tsv)...
# 13  Part 3            3  Upload and access a comma-separated value (.cs...
# 14  Part 3            4             Access data from an Excel file (.xlsx)
# 15  Part 3            5                        Access text data from a URL
