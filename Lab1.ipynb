# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahesh-ch06/AIML_2303A52037/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PART-01**

# %% [markdown]
# **Part 01: Lab Task is implement the following data structures using Numpy and Pandas.**
#
# 1.Lists
# 2.Arrays
# 3.Identify their type using type()
# 4.Perform mathematical operations on these datasets created - multiplication, division, poweroff
# 5.Combine text with Numpy fuction to generate a textual output - ”Addition of Two: array1 +array 2
# 6.Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
list1 = [1,2,3,4]
list2 = [5,6,7,8]
array1 = np.array(list1)
array2 = np.array(list2)
array1
array2
# Out:
# array([5, 6, 7, 8])

# %%
print(type(list1))
print(type(array1))
print(type(list2))
print(type(array2))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'list'>
# <class 'numpy.ndarray'>

# %% [markdown]
#  **Perform Mathematical Operations on these datasets -Multiplication, Division, Poweroff**

# %%
mul = array1*array2
div = array1/array2
power = np.power(array1,2)

# %%
print("mul of two arrays",mul)
print("div of two arrays",div)
print("power of two arrays",power)
# Out:
# mul of two arrays [ 5 12 21 32]
# div of two arrays [0.2        0.33333333 0.42857143 0.5       ]
# power of two arrays [ 1  4  9 16]

# %% [markdown]
# **Perform Mathematical Operations on these datasets - sin and log operation**

# %%
print("Sine: ",np.sin(array1))
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
print("Exponential: ",np.exp(array1))
# Out:
# Sine:  [ 0.84147098  0.90929743  0.14112001 -0.7568025 ]
# Natural logarithm:  [0.         0.69314718 1.09861229 1.38629436]
# Base-10 logarithm:  [0.         0.30103    0.47712125 0.60205999]
# Base-2 logarithm:  [0.        1.        1.5849625 2.       ]
# Exponential:  [ 2.71828183  7.3890561  20.08553692 54.59815003]

# %%
print("Adding of two arrays:", array1+array2)
# Out:
# Adding of two arrays: [ 6  8 10 12]

# %% [markdown]
# **PART-02**

# %% [markdown]
# **Part-02: Lab Task is to visualize the datasets or data using Matplotlib builtin function Graphs
# Generate Scatterplot
# Let's suppose we collected age (in years), height (in cm), and weight (in kilograms) information from few patients visitng a clinic.**

# %%
import matplotlib.pyplot as plt

# %%
people = ['Mahesh','Chodhitha','Charvika','Tharun','Nikhil','Niteesh',]
age = [17,18,21,26,27,22]
weight = [55,35,77,56,53,56]
height = [170,160,165,156,179,142]

# %%
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %% [markdown]
# **Generate Bar Plot**

# %%
plt.figure(figsize=(12,8))
plt.title("People's weight in kgs",fontsize=18,
          fontstyle='italic')
plt.bar(x=people,height=weight, width=0.7,
        color='blue',edgecolor='k',alpha=0.8)
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=17)
plt.show()

# %% [markdown]
# **Generate Histogram**

# %%
plt.figure(figsize=(9,6))
plt.hist(weight,color='purple',edgecolor='k', alpha=0.75,bins=5)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# **PART-03**

# %% [markdown]
# **Part-03: Access Data from various sources and formats**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **TEXT FILE**

# %%
data1 = pd.read_table("Lab01-Text.txt")

# %%
data1
# Out:
#    ID     Person  Age  Weight  Height       City         Occupation  \
# 0   1     Mahesh   17      55     170     Mumbai            Student
# 1   2  Chodhitha   18      35     160       Pune            Student
# 2   3   Charvika   21      77     165  Bangalore  Software Engineer
# 3   4     Tharun   26      56     156      Delhi     Data Scientist
# 4   5     Nikhil   27      53     179  Hyderabad           Engineer
# 5   6    Niteesh   22      56     142    Chennai            Student
#
#                  Email
# 0     mahesh@gmail.com
# 1  chodhitha@gmail.com
# 2   charvika@gmail.com
# 3     tharun@gmail.com
# 4     nikhil@gmail.com
# 5    niteesh@gmail.com

# %% [markdown]
# **CSV FILE**

# %%
data2 = pd.read_csv("Lab01-Text.csv")

# %%
data2
# Out:
#    ID     Person  Age  Weight  Height       City         Occupation  \
# 0   1     Mahesh   17      55     170     Mumbai            Student
# 1   2  Chodhitha   18      35     160       Pune            Student
# 2   3   Charvika   21      77     165  Bangalore  Software Engineer
# 3   4     Tharun   26      56     156      Delhi     Data Scientist
# 4   5     Nikhil   27      53     179  Hyderabad           Engineer
# 5   6    Niteesh   22      56     142    Chennai            Student
#
#                  Email
# 0     mahesh@gmail.com
# 1  chodhitha@gmail.com
# 2   charvika@gmail.com
# 3     tharun@gmail.com
# 4     nikhil@gmail.com
# 5    niteesh@gmail.com

# %% [markdown]
# **MS Excel**

# %%
data3 = pd.read_excel("Height_weight.xlsx")

# %%
data3
# Out:
#         Name  Height (cm)  Weight (kg)
# 0     Mahesh          170           55
# 1  Chodhitha          160           35
# 2   Charvika          165           77
# 3     Tharun          156           56
# 4     Nikhil          179           53
# 5    Niteesh          142           56

# %% [markdown]
# **TSV FILE**

# %%
data4 = pd.read_csv("Lab01-Text.tsv", delimiter='\t')

# %%
data4
# Out:
#    ID     Person  Age  Weight  Height       City         Occupation  \
# 0   1     Mahesh   17      55     170     Mumbai            Student
# 1   2  Chodhitha   18      35     160       Pune            Student
# 2   3   Charvika   21      77     165  Bangalore  Software Engineer
# 3   4     Tharun   26      56     156      Delhi     Data Scientist
# 4   5     Nikhil   27      53     179  Hyderabad           Engineer
# 5   6    Niteesh   22      56     142    Chennai            Student
#
#                  Email
# 0     mahesh@gmail.com
# 1  chodhitha@gmail.com
# 2   charvika@gmail.com
# 3     tharun@gmail.com
# 4     nikhil@gmail.com
# 5    niteesh@gmail.com

# %% [markdown]
# **IMAGE**

# %%
from PIL import Image
image = Image.open('AIML.png')

# %%
plt.figure(figsize=(8,6))
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# **READING DATA**

# %%
His_Price = pd.read_csv('/content/HistoricalPrices (1).csv', delimiter='\t')
His_Price
# Out:
#                       Date, Open, High, Low, Close
# 0   08-07-2024,39230.09,39477.96,38731.51,38763.45
# 1    08-06-2024,38736.22,39449.53,38638.3,38997.66
# 2   08-05-2024,39056.19,39056.19,38499.27,38703.27
# 3   08-02-2024,40075.33,40075.33,39358.68,39737.26
# 4   08-01-2024,40916.96,41096.66,40098.57,40347.97
# ..                                             ...
# 60  05-10-2024,39466.52,39579.88,39406.26,39512.84
# 61  05-09-2024,39064.27,39413.66,38988.85,39387.76
# 62   05-08-2024,38818.9,39094.74,38814.99,39056.39
# 63   05-07-2024,38858.94,38977.61,38840.4,38884.26
# 64  05-06-2024,38762.43,38886.47,38689.38,38852.27
#
# [65 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
# ...

# %% [markdown]
# **PROBLEM 1 : BAR PLOT**

# %%
Classes = ['Class A','Class B','Class C','Class b','Class D']
age = [23, 17, 30, 25, 19]

# %%
plt.scatter(Classes, age)
plt.title("Number Of Student In Each Class")
plt.ylabel("Number Of Students")
plt.xlabel("Classes")
plt.show()
